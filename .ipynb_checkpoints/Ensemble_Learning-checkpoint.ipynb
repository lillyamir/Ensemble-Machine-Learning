# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
import warnings
from sklearn.tree import plot_tree
import warnings
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from itertools import cycle

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Data Cleaning

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
# data (as pandas dataframes) 
X = heart_disease.data.features 
y = heart_disease.data.targets

# %%
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal
# 0  0.0   6.0
# 1  3.0   3.0
# 2  2.0   7.0
# 3  0.0   3.0
# 4  0.0   3.0

# %%
# target variable is presence of heart disease in the patient - 0 (no presence) to 4. 
y.head()
# Out:
#    num
# 0    0
# 1    2
# 2    1
# 3    0
# 4    0

# %%
#Merge the data frames
if len(y) == len(X):
    dat = X.join(y, how='outer')
    
dat.head()
dat = dat.dropna(axis=0)

# %%
#Check for missing values and remove those rows
print(len(dat))

dat = dat.dropna(axis = 0)

print(len(dat))
#We dropped 6 rows that have missing values
# Out:
# 297
# 297

# %% [markdown]
# ### Feature Engingeering

# %%
#Binning Age: Divide age into predefined categories
dat['age_group'] = pd.cut(dat['age'], bins=[0, 30, 45, 60, 75, 100],
                         labels=['<30', '30-45', '45-60', '60-75', '>75'])

# %%
#Hypertension Flag
dat['hypertension'] = (dat['trestbps'] >= 140).astype(int)

# %%
#Cholesterol Risk
dat['cholesterol_risk'] = pd.cut(dat['chol'],
                                bins=[0, 200, 239, np.inf],
                                labels=['Desirable', 'Borderline high', 'High'])

# %%
#Interaction Terms
dat['age_cholesterol'] = dat['age'] * dat['chol']

# %% [markdown]
# ### Rename columns

# %%
dat = dat.rename(columns={"thalach": "max_heart_rate", "oldpeak": "depression", "num": "heart_disease_diagnosis",
                   'exang': "exercise_induced_angina", "fbs": 'fasting_blood_sugar', 'ca': 'num_major_vessels',
                   'cp': 'chest_pain_type'})
dat.head()
# Out:
#    age  sex  chest_pain_type  trestbps  chol  fasting_blood_sugar  restecg  \
# 0   63    1                1       145   233                    1        2
# 1   67    1                4       160   286                    0        2
# 2   67    1                4       120   229                    0        2
# 3   37    1                3       130   250                    0        0
# 4   41    0                2       130   204                    0        2
#
#    max_heart_rate  exercise_induced_angina  depression  slope  \
# 0             150                        0         2.3      3
# 1             108                        1         1.5      2
# 2             129                        1         2.6      2
# 3             187                        0         3.5      3
# 4             172                        0         1.4      1
#
#    num_major_vessels  thal  heart_disease_diagnosis age_group  hypertension  \
# 0                0.0   6.0                        0     60-75             1
# 1                3.0   3.0                        2     60-75             1
# 2                2.0   7.0                        1     60-75             0
# 3                0.0   3.0                        0     30-45             0
# 4                0.0   3.0                        0     30-45             0
#
#   cholesterol_risk  age_cholesterol
# 0  Borderline high            14679
# 1             High            19162
# 2  Borderline high            15343
# 3             High             9250
# 4  Borderline high             8364

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Visual Analysis

# %%
# Age Group vs. Systolic Blood Pressure
plt.figure(figsize=(10, 6))
sns.boxplot(x='age_group', y='trestbps', data=dat)
plt.title('Age Group vs. Blood Pressure')
plt.show()

# %%
# Age Group vs. Cholesterol Risk
plt.figure(figsize=(10, 6))
sns.countplot(x='age_group', hue='cholesterol_risk', data=dat)
plt.title('Age Group vs. Cholesterol Risk')
plt.show()

# %%
# Hypertension Flag Distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='hypertension', data=dat)
plt.title('Distribution of Hypertension Flag')
plt.xlabel('Hypertension (0 = No, 1 = Yes)')
plt.show()

# %%
# Scatter Plot of Age and Cholesterol
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='chol', hue='hypertension', data=dat)
plt.title('Scatter Plot of Age vs. Total Cholesterol')
plt.show()

# %% [markdown]
# ### Descriptive Statistics

# %%
# Descriptive Statistics
print("Descriptive Statistics:")
print(dat[['age', 'trestbps', 'chol', 'heart_disease_diagnosis']].describe())

# Correlation Matrix
print("\nCorrelation Matrix:")
print(dat[['age', 'trestbps', 'chol', 'heart_disease_diagnosis']].corr())
# Out:
# Descriptive Statistics:
#               age    trestbps        chol  heart_disease_diagnosis
# count  297.000000  297.000000  297.000000               297.000000
# mean    54.542088  131.693603  247.350168                 0.946128
# std      9.049736   17.762806   51.997583                 1.234551
# min     29.000000   94.000000  126.000000                 0.000000
# 25%     48.000000  120.000000  211.000000                 0.000000
# 50%     56.000000  130.000000  243.000000                 0.000000
# 75%     61.000000  140.000000  276.000000                 2.000000
# max     77.000000  200.000000  564.000000                 4.000000
#
# Correlation Matrix:
#                               age  trestbps      chol  heart_disease_diagnosis
# age                      1.000000  0.290476  0.202644                 0.222156
# trestbps                 0.290476  1.000000  0.131536                 0.159620
# chol                     0.202644  0.131536  1.000000                 0.066448
# heart_disease_diagnosis  0.222156  0.159620  0.066448                 1.000000

# %% [markdown]
# ## Model Building

# %%
X = dat.drop(['heart_disease_diagnosis', 'age_group', 'cholesterol_risk'], axis=1)
y = dat['heart_disease_diagnosis']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)


# Ensure y_train is properly formatted as a Series
if isinstance(y_train, pd.DataFrame):
    y_train = y_train.iloc[:, 0]  # Assuming y_train should be a single column from a DataFrame

# Calculate mode and handle potentially empty results
mode_value = y_train.mode()
if mode_value.empty:
    print("Mode computation returned an empty result. No mode to fill NaN values.")
else:
    # Fill NaN values with the first mode found
    y_train.fillna(mode_value.iloc[0], inplace=True)

if X_train.isnull().any().any():
    X_train = X_train.fillna(X_train.mean())

# Check for infinite values
if np.isinf(X_train.values).any():
    X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
    X_train = X_train.fillna(X_train.mean())

# %% [markdown]
# ### Random Forest Classifier

# %%
# creating a RF classifier
clf = RandomForestClassifier(n_estimators = 100)  
 
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
clf.fit(X_train, y_train)
 
# performing predictions on the test dataset
y_pred = clf.predict(X_test)
 
# metrics are used to find accuracy or error
from sklearn import metrics  
print()
 
# using metrics module for accuracy calculation
print("ACCURACY OF THE MODEL:", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL: 0.5555555555555556

# %% [markdown]
# ### Decision Tree Classifier

# %%
clf = DecisionTreeClassifier(random_state=1)
param_grid = {
    'max_depth': range(1, 10, 1),
    'min_samples_leaf': range(1, 20, 2),
    'min_samples_split': range(2, 20, 2),
    'criterion': ["entropy", "gini"]
}

clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
feature_names = X_train.columns.tolist()  # Ensure these are the names of the features
class_names = ['Class 0', 'Class 1', 'Class 2', 'Class 3', 'Class 4']  # Adjust as necessary

plt.figure(figsize=(20,10))  # Adjust the size as needed
plot_tree(clf, filled=True, feature_names=feature_names, class_names=class_names)
plt.show()

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Decision Tree Classifier

# %%
# Get feature importances
importances = clf.feature_importances_

# Create a DataFrame for visualization
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the feature importances
print(feature_importance_df)

# Visualize feature importances
plt.figure(figsize=(10,6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance')
plt.show()
# Out:
#                     Feature  Importance
# 9                depression    0.161633
# 12                     thal    0.157677
# 11        num_major_vessels    0.144142
# 4                      chol    0.120001
# 7            max_heart_rate    0.089778
# 2           chest_pain_type    0.086531
# 14          age_cholesterol    0.062233
# 0                       age    0.058242
# 3                  trestbps    0.048085
# 8   exercise_induced_angina    0.018062
# 10                    slope    0.015720
# 1                       sex    0.015319
# 5       fasting_blood_sugar    0.015051
# 6                   restecg    0.007526
# 13             hypertension    0.000000

# %%
top_features = feature_importance_df['Feature'].head(4)  # Select top 4 features

# Subset the training and testing data to include only the top 4 features
X_train_top = X_train[top_features]
X_test_top = X_test[top_features]

# %%
# Ensure top_features is converted to a list explicitly if it's not already
top_features_list = top_features.tolist()

# Initialize and fit the Decision Tree Classifier
clf_top_features = DecisionTreeClassifier(max_depth=3, random_state=1)
clf_top_features.fit(X_train_top, y_train)

# Plot the decision tree with the correct list of feature names
plt.figure(figsize=(12,8))  # Adjust the size as needed
plot_tree(clf_top_features, filled=True, feature_names=top_features_list, class_names=class_names)
plt.title('Decision Tree with Top 4 Features')
plt.show()

# %%
# Make predictions
y_pred_top = clf_top_features.predict(X_test_top)

# Calculate accuracy
accuracy_top = accuracy_score(y_test, y_pred_top)
print("Accuracy of the model with top 4 features:", accuracy_top)

# Additional detailed classification report
print(classification_report(y_test, y_pred_top))
# Out:
# Accuracy of the model with top 4 features: 0.5222222222222223
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.82        48
#            1       0.10      0.08      0.09        13
#            2       0.00      0.00      0.00        16
#            3       0.20      0.67      0.31         9
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.52        90
#    macro avg       0.22      0.32      0.24        90
# weighted avg       0.46      0.52      0.48        90

# %% [markdown]
# ### Random Forest Classifier

# %%
# Initialize the Random Forest Classifier
rfc_top_features = RandomForestClassifier(n_estimators=100, random_state=1)
rfc_top_features.fit(X_train_top, y_train)

# Make predictions on the test data
y_pred_rf = rfc_top_features.predict(X_test_top)

# Calculate accuracy
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print("Accuracy of the Random Forest model with top 4 features:", accuracy_rf)

# Detailed classification report
print(classification_report(y_test, y_pred_rf))
# Out:
# Accuracy of the Random Forest model with top 4 features: 0.5222222222222223
#               precision    recall  f1-score   support
#
#            0       0.69      0.77      0.73        48
#            1       0.08      0.08      0.08        13
#            2       0.50      0.25      0.33        16
#            3       0.36      0.56      0.43         9
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.52        90
#    macro avg       0.32      0.33      0.31        90
# weighted avg       0.50      0.52      0.50        90

# %%
# Get feature importances
importances_rf = rfc_top_features.feature_importances_

# Create a DataFrame for easier visualization
importances_df_rf = pd.DataFrame({
    'Feature': top_features_list,
    'Importance': importances_rf
})
importances_df_rf = importances_df_rf.sort_values(by='Importance', ascending=False)


plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=importances_df_rf)
plt.title('Feature Importance in Random Forest')
plt.show()

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
# Initialize Gradient Boosting Classifier
gbc_top_features = GradientBoostingClassifier(n_estimators=100, random_state=1)
gbc_top_features.fit(X_train_top, y_train)
# Out:
# GradientBoostingClassifier(random_state=1)

# %% [markdown]
# ## Ensemble Learning Implementation

# %% [markdown]
# ### Voting Classifier

# %%
voting_clf = VotingClassifier(
    estimators=[
        ('decision_tree', clf_top_features),
        ('random_forest', rfc_top_features),
        ('gradient_boosting', gbc_top_features)
    ],
    voting='soft'  # soft voting returns the average of probabilities
)
voting_clf.fit(X_train_top, y_train)

# Make predictions and evaluate the ensemble model
y_pred_voting = voting_clf.predict(X_test_top)
accuracy_voting = accuracy_score(y_test, y_pred_voting)
print("Accuracy of the Voting Classifier:", accuracy_voting)
# Out:
# Accuracy of the Voting Classifier: 0.5

# %%
# Initialize the stacking classifier
stacking_clf = StackingClassifier(
    estimators=[
        ('decision_tree', clf_top_features),
        ('random_forest', rfc_top_features),
        ('gradient_boosting', gbc_top_features)
    ],
    final_estimator=LogisticRegression()  # Logistic Regression as the final estimator
)
stacking_clf.fit(X_train_top, y_train)

# Make predictions and evaluate the ensemble model
y_pred_stacking = stacking_clf.predict(X_test_top)
accuracy_stacking = accuracy_score(y_test, y_pred_stacking)
print("Accuracy of the Stacking Classifier:", accuracy_stacking)
# Out:
# Accuracy of the Stacking Classifier: 0.5777777777777777

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Cross Validation

# %%
# Evaluating the Voting Classifier using cross-validation
voting_scores = cross_val_score(voting_clf, X_train_top, y_train, cv=5, scoring='accuracy')
print("Voting Classifier Cross-Validated Scores:", voting_scores)
print("Average Accuracy:", voting_scores.mean())

# Evaluating the Stacking Classifier using cross-validation
stacking_scores = cross_val_score(stacking_clf, X_train_top, y_train, cv=5, scoring='accuracy')
print("Stacking Classifier Cross-Validated Scores:", stacking_scores)
print("Average Accuracy:", stacking_scores.mean())
# Out:
# Voting Classifier Cross-Validated Scores: [0.52380952 0.52380952 0.63414634 0.48780488 0.58536585]
# Average Accuracy: 0.5509872241579559
# Stacking Classifier Cross-Validated Scores: [0.5        0.52380952 0.6097561  0.48780488 0.6097561 ]
# Average Accuracy: 0.5462253193960511

# %% [markdown]
# ### Performance Metrics

# %%
# Binarize the labels for one-vs-rest computation
y_test_binarized = label_binarize(y_test, classes=np.unique(y_train))

# Compute ROC curve and ROC area for each class
n_classes = y_test_binarized.shape[1]
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    # Getting predicted probabilities for each class
    y_prob = voting_clf.predict_proba(X_test_top)[:, i]
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_prob)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'red'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'ROC curve of class {i} (area = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-class ROC Curve')
plt.legend(loc="lower right")
plt.show()
